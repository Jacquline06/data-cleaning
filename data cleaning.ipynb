# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\Sam Joseph Britto\\Downloads\\content\\SAMPLE.csv")
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.fillna(20,inplace=True)

# %%
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0    20.0   20                   20  20.00  20.0     20.0   20.0
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   20.0
# 3     3.0   A3      ANNA UNIVERSITY  20.00  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                   20  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  20.0      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY  20.00  85.6      6.0   99.0
# 11   20.0   20                   20  20.00  20.0     20.0   20.0
# 12   20.0   20                   20  20.00  20.0     20.0   20.0
# ...

# %%
df=pd.read_csv("C:\\Users\\Sam Joseph Britto\\Downloads\\content\\SAMPLE.csv")
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\Sam Joseph Britto\AppData\Local\Temp\ipykernel_19116\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0   95.0
# 3     3.0   A3      ANNA UNIVERSITY  76.80  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5  ANAMALAI UNIVERSITY  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80  88.1      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# ...

# %%
df["hsc"].fillna(value=df["hsc"].mean(),inplace=True)
df
# Out:
# C:\Users\Sam Joseph Britto\AppData\Local\Temp\ipykernel_19116\1816244588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["hsc"].fillna(value=df["hsc"].mean(),inplace=True)
#     sl No name              college        hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN  88.052667   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.900000  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.800000  77.9      3.0    NaN
# ...

# %%
df["cmark"].fillna(value=df["cmark"].max(),inplace=True)
df
# Out:
# C:\Users\Sam Joseph Britto\AppData\Local\Temp\ipykernel_19116\3983484408.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cmark"].fillna(value=df["cmark"].max(),inplace=True)
#     sl No name              college        hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN  88.052667   NaN      NaN   99.0
# 1     1.0   A1                 IITM  89.900000  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.800000  77.9      3.0   99.0
# ...

# %%
df=pd.read_csv("C:\\Users\\Sam Joseph Britto\\Downloads\\content\\SAMPLE.csv")
df
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.dropna(how='any')
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df.dropna(how='all',axis=1)#axis 1 is for column and axis 0 is for row
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 11    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# ...

# %%
df.dropna(how='any',subset=["hsc","SSLC","cmark"]) #here we are droping for subset columns
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# 18   14.0  A13                  SRM  86.90  97.0     33.0   92.0
# 19    3.0   A3      ANNA UNIVERSITY  88.39  85.6      6.0   99.0

# %%
df.dropna(how='all',subset=["hsc","SSLC","cmark"])
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df.drop_duplicates(keep = "first")#it is remove the first duplicate row
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 0     NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 3     3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df.drop_duplicates(keep = "last")#it is remove from last duplicate row
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 10    3.0   A3      ANNA UNIVERSITY    NaN  85.6      6.0   99.0
# 12    NaN  NaN                  NaN    NaN   NaN      NaN    NaN
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# ...

# %%
df.duplicated(keep=False)
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.drop_duplicates(keep = False)#it will remove the true value from that row
# Out:
#     sl No name              college    hsc  SSLC  arrears  cmark
# 1     1.0   A1                 IITM  89.90  92.6      0.0   95.0
# 2     2.0   A2      ANNA UNIVERSITY  76.80  77.9      3.0    NaN
# 4     4.0   A4  ANAMALAI UNIVERSITY  92.50  94.6      1.0   76.0
# 5     5.0   A5                  NaN  79.30  65.0      2.0   89.0
# 6     6.0   A6                  SRM  99.80  88.1      0.0   89.6
# 7     7.0   A7             SAVEETHA  91.80   NaN      7.0   78.3
# 8     8.0   A8             SAVEETHA  99.80  65.8     66.0   77.5
# 9    56.0  A34             SAVEETHA  99.80  99.8      5.0   77.5
# 13    9.0   A9  ANAMALAI UNIVERSITY  98.70  91.0      2.0   76.0
# 14   10.0   AD               fogjof  56.00   9.0      NaN    2.0
# 15   11.0  A10                 IITM  94.00  77.6      1.0   75.0
# 16   12.0  A11                  NaN  88.20   NaN      2.0   72.0
# 17   13.0  A12            dhgvuicbh  78.90  84.9      3.0   83.0
# ...
